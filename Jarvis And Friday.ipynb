# %%
import pyttsx3
import datetime
import pyaudio
import wikipedia
import webbrowser
import os
import smtplib
import speech_recognition as sr

# %%
 engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
print(voices[1].id)
engine.setProperty('voice', voices[0].id)
    
    
    
    
def speak(audio):
    engine.say(audio)
    engine.runAndWait()
    
    
def wishMe():
    hour = int(datetime.datetime.now().hour)
    if hour>=0 and hour<12:
        print("Good Morning Omkar Sir!")
        speak("Good Morning Omkar Sir!")
        
    elif hour>=12 and hour<18:
        print("Good Afternoon Omkar Sir!")
        speak("Good Afternoon Omkar Sir!")
        
    else:
        print("Good Evening Omkar Sir!")
        speak("Good Evening Omkar Sir!")  
    speak("I  am Jarvis , how can i help you  Sir")
    
    

                
    
    
def takeCommand():
    r= sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        r.pause_threshold = 1
        audio = r.listen(source)
        
        
        
    try:
        print("Recognizing....")
        query = r.recognize_google(audio, language='en-in')
        print(f"User said:{query}\n")
        
        
    except Exception as e:
#         print(e)
        print("Say that again please...")
        return "None"
    return query
    
def sendEmail(to,content):
    server = smtplib.SMTP('smtp.gmail.com',587)
    server.ehlo()
    server.starttls()
    server.login('omkarg634@gmail.com','*********')
    server.sendmail('omkarg634@gmail.com',to,content)
    server.close()
    

if __name__ == "__main__":
    wishMe()
    
    while True:
        query = takeCommand().lower()
        
        
        # logic for executing tasks based on query
        if 'wikipedia' in query:
            speak('Searching Wikipedia...')
            query=query.replace("wikipedia","")
            results = wikipedia.summary(query, sentences=10)
            speak("According to wikipedia")
            print(results)
            speak(results)
            
            
        elif'how are you jarvis' in query:
             speak('i am good sir,what about you ?')
                
        elif'kaise ho ' in query:   
             speak('i am good sir,what about you ?')
                
                
        elif'how are you friday' in query:
             speak('i am good sir,what about you ?')
                
        elif'i am also good' in query:
            print("Nice to here that 😊")
            speak("Nice to here that")
            
        elif'i am also fine' in query:
            print("Nice to here that 😊")
            speak("Nice to here that")
            
        elif'hey jarvis' in query:
            speak("Yes Sir, how may i help you")
            
        elif'who is the egoistic person in my class' in query:
            print("Drashti Wala 😂")
            speak("Drashti Wala, is the egoistic person in your class,sir ")
        
        elif'who is the cutest person in my class' in query:
            print("You ❤️❤️❤️")
            speak("it's ,you ")
            
                
        elif'love you' in query:
            speak("love you two sir")
            
        elif'what is my name' in query:
            speak('Sir, your name is omkar pushpa arun gupta')
            
        elif'say some motivational line' in query:
            speak(" if you have money : people will say How are you? and if you don't have money : people will say who are you?")
            
        elif'kya kar rahe ho ' in query: 
            speak(" talking with my favourite person !!! ")
            
        elif'what are you doing' in query:
            speak(" talking with my favourite person!!!")
            
        elif'how to impress a girl' in query:
            speak(" don't impress any girls , insteaded, just focus on your career")
            
        
        elif'open youtube' in query:
            webbrowser.open("youtube.com")
            
        elif'open google' in query:
            webbrowser.open("google.com")
            
        elif'open camera' in query:
            webbrowser.open("camera")
        
#         elif'play music' in query:
#             music=C\\Users\\Omkar\\Downloads\\Closer---The-Chainsmokers-ft.-Halsey-320(PagalWorld).mp3
#             songs = os.listen(music)
#             print(songs)
#             os.startfile(os.path.join(music,song[0]))
            
        elif 'the time' in query:
            strTime = datetime.datetime.now().strftime("%H:%M:%S")
            print(strTime)
            speak(f"Sir,the time is {strTime}")
            
        elif'open vs code' in query:
            codePath="C:\\Users\\Omkar\\AppData\\Local\\Programs\\Microsoft VS Code\\Code.exe"
            os.startfile(codePath)
            
        elif'open excel' in query:
            excelPath="C:\\Program Files\\Microsoft Office\\root\\Office16\\EXCEL.EXE"
            os.startfile(excelPath)
            
        elif'open powerpoint' in query:
            ppPath="C:\\Program Files\\Microsoft Office\\root\\Office16\\POWERPNT.EXE"
            os.startfile(ppPath)
            
        elif'open word' in query:
            wordPath="C:\\Program Files\\Microsoft Office\\root\\Office16\\WINWORD.EXE"
            os.startfile(wordPath)
            

            
            
        elif'email to omkar' in query:
            try:
                speak("What should i say?")
                content = takeCommand()
                to="omkarg634@gmail.com"
                sendEmail(to,content)
                speak("Email has been sent!")
            except Exception as e:
                print(e)
                print("Sorry Omkar Sir, I am not able to send this Email😞")
                speak("Sorry Omkar Sir, I am not able to send this Email😞")
# Out:
# HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_EN-US_ZIRA_11.0
# Good Afternoon Omkar Sir!
